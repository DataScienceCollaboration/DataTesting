# %%
import pandas as pd
payment_summary = pd.read_csv('Inpatient_Prospective_Payment_System__IPPS__Provider_Summary_for_the_Top_100_Diagnosis-Related_Groups__DRG__-_FY2011 copy.csv', dtype = str)

# %% [markdown]
# What is Project Question?

# %%
IN_summary = payment_summary[payment_summary['Provider State']=='IN']
print(IN_summary.shape)
IN_summary.head(20)
# Out:
# (4260, 12)
#                                DRG Definition Provider Id  \
# 331  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      150002
# 332  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      150009
# 333  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      150012
# 334  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      150015
# 335  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      150017
# 336  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      150018
# 337  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      150021
# 338  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      150023
# 339  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      150026
# 340  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      150034
# 341  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      150035
# 342  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      150042
# 343  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      150044
# 344  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      150046
# 345  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      150048
# ...

# %% [markdown]
# In order to check it we need to make sure patterns are properly followed:
#
# DRG: Unclear
#
# Provider Id: Number - unclear miniumum or maximum lengths
#
# Provider ZipCode: Number, only 5 digits
#
# Hospital Region: Two letters dash letters
#
# Convert charges to numbers

# %%
OH_summary = payment_summary[payment_summary['Provider State']=='OH']
print(OH_summary.shape)
# Out:
# (7012, 12)

# %%
pattern = r'4[67]\d{3}'
bool1 = IN_summary['Provider Zip Code'].str.match(pattern)
bool2 = ~bool1
IN_zip_error = IN_summary[bool2]
print(IN_zip_error['Provider Zip Code'])
# Out:
# Series([], Name: Provider Zip Code, dtype: object)

# %%
pattern2 = r'IN \- .*'
bool3 = payment_summary['Hospital Referral Region Description'].str.match(pattern2)
IN_regions_sum = payment_summary[bool3]
print(IN_regions_sum.shape)
IN_regions_sum.head(20)
# Out:
# (4117, 12)
#                                DRG Definition Provider Id  \
# 331  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      150002
# 333  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      150012
# 334  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      150015
# 335  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      150017
# 336  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      150018
# 337  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      150021
# 338  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      150023
# 339  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      150026
# 340  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      150034
# 341  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      150035
# 342  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      150042
# 344  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      150046
# 345  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      150048
# 346  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      150051
# 347  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      150056
# ...

# %%
pattern4 = r'4[67]\d{3}'
bool4 = IN_regions_sum['Provider Zip Code'].str.match(pattern)
bool5 = ~bool4
Not_IN = IN_regions_sum[bool5]
print(Not_IN.shape)
# Out:
# (157, 12)
